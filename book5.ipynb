# %%
import pandas
marks = pandas.read_excel('/home/niraj/Desktop/book5.xlsx')

# %%
marks
# Out:
#               rn        sn                       name        dob  en_th  \
# 0   782330220001  13302275             Aarti Shreshta        NaT   46.0
# 1   782330220002  13302276                Abhisek Raj 2061-03-26   40.0
# 2   782330220003  13302277              Abhisek Yadav 2060-03-08   40.0
# 3   782330220004  13302278               Amisha Yadav 2060-05-27    NaN
# 4   782330220005  13302279          Amrita Chaurasiya 2062-01-05   42.0
# ..           ...       ...                        ...        ...    ...
# 74  782330220075  13302349  Tej Narayan Prasad Mandal 2060-12-25   40.0
# 75  782330220076  13302350         Umesh Kumar Mandal 2055-07-05   40.0
# 76  782330220077  13302351            Utam Kumar Ojha 2061-01-10   45.0
# 77  782330220078  13302352         Yad Hussain Hawari 2062-07-11   40.0
# 78  782330220079  13302353              Yantom Tamang 2050-09-04   40.0
#
#     en_pr  ne_th  ne_pr  so_th  so_pr  ...  ac_th  ac_pr  ch_th  ch_pr  ed_th  \
# ...

# %%
mark_dict = marks.to_dict()

# %%
mark_dict
# Out:
# {'rn': {0: 782330220001,
#   1: 782330220002,
#   2: 782330220003,
#   3: 782330220004,
#   4: 782330220005,
#   5: 782330220006,
#   6: 782330220007,
#   7: 782330220008,
#   8: 782330220009,
#   9: 782330220010,
#   10: 782330220011,
#   11: 782330220012,
#   12: 782330220013,
#   13: 782330220014,
#   14: 782330220015,
#   15: 782330220016,
#   16: 782330220017,
#   17: 782330220018,
#   18: 782330220019,
#   19: 782330220020,
#   20: 782330220021,
#   21: 782330220022,
#   22: 782330220023,
#   23: 782330220024,
#   24: 782330220025,
#   25: 782330220026,
#   26: 782330220027,
#   27: 782330220028,
#   28: 782330220029,
#   29: 782330220030,
#   30: 782330220031,
#   31: 782330220032,
#   32: 782330220033,
#   33: 782330220034,
#   34: 782330220035,
#   35: 782330220036,
#   36: 782330220037,
#   37: 782330220038,
#   38: 782330220039,
#   39: 782330220040,
#   40: 782330220041,
#   41: 782330220042,
#   42: 782330220043,
#   43: 782330220044,
#   44: 782330220045,
# ...
