# %%
import pandas
marks = pandas.read_excel('book5.xlsx')

# %%
expr = marks.copy()

# %%
#access by last digit of registeration no
def student(last_digit):
    regno = 782330220000 + last_digit
    return expr.loc[expr['rn'] == regno]

# %%
def marksheet(last_digit):
    temp = student(last_digit)
    temp = temp.iloc[:,4:]
    temp = temp.dropna(axis = 1)
    return temp

# %%
def conv_gp(num):
    if (num == 25):
        temp = 0
    if (num >25):
        temp = (num/75)*100
    else:
        temp = (num/25)*100
        
    if (temp >= 90):
        gp = 4.0
        return gp
    if(temp<90) & (temp>=80):
        gp = 3.6
        return gp
    if(temp<80) & (temp>=70):
        gp = 3.2
        return gp
    if(temp<70) & (temp >=60):
        gp = 2.8
        return gp
    if(temp<60) & (temp >=50):
        gp = 2.4
        return gp
    if(temp<50) & (temp >= 40):
        gp = 2.0
        return gp
    if(temp<40) & (temp >=35):
        gp = 1.6
        return gp
    else:
        gp = 0
        return gp

# %%
def a(n):
    if n >25:
        g = n/75
    else:
        g = n/25
    return g
marksheet(6).apply(a,axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_219/3535521252.py in <module>
#       5         g = n/25
#       6     return g
# ----> 7 marksheet(6).apply(a,axis=1)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# ...
